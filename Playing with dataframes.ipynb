# %%
import pandas as pd
import datetime as dt

# %%
df = pd.read_pickle("Data/III/AMER.L.pkl")

# %%
df.head(50)
# Out:
#                author                                            comment  \
# 0      Tank Commander  \n\tAppreciate you insight on the new fields, ...
# 1           II Editor  \n\t"Oil industry analyst Malcolm Graham-Wood ...
# 2        kynance cove  \n\nQuote\nAmerisur Resources\nI wrote about A...
# 3            spike501  \n\tTC - the new fields are in the Llanos basi...
# 4      Tank Commander  \n\nHi All\n\nJust to say I was puzzled by the...
# 5         bigwavedave  \nhttp://www.iii.co.uk/articles/271031/3-oil-s...
# 6              fadilz  \n\tsorry meant to respond rather than tick up...
# 7            celeriac  \n\tanyone got an estimate for the release dat...
# 8   hammersandpodgers  \n\tPPC - have just upped there prospective re...
# 9             Sumperk  \n\tI wonder how Elena Deramper Saratov is get...
# 10            MISOLDB                                  \n\tAnd riseing\t
# 11         mintington  \n\tIs this a classic buy on rumour ( Loto 2 r...
# ...

# %%
df.sort_values('date', ascending = False).head(50)
# Out:
#                author                                            comment  \
# 0      Tank Commander  \n\tAppreciate you insight on the new fields, ...
# 1           II Editor  \n\t"Oil industry analyst Malcolm Graham-Wood ...
# 2        kynance cove  \n\nQuote\nAmerisur Resources\nI wrote about A...
# 3            spike501  \n\tTC - the new fields are in the Llanos basi...
# 4      Tank Commander  \n\nHi All\n\nJust to say I was puzzled by the...
# 8   hammersandpodgers  \n\tPPC - have just upped there prospective re...
# 9             Sumperk  \n\tI wonder how Elena Deramper Saratov is get...
# 10            MISOLDB                                  \n\tAnd riseing\t
# 7            celeriac  \n\tanyone got an estimate for the release dat...
# 6              fadilz  \n\tsorry meant to respond rather than tick up...
# 5         bigwavedave  \nhttp://www.iii.co.uk/articles/271031/3-oil-s...
# 11         mintington  \n\tIs this a classic buy on rumour ( Loto 2 r...
# ...

# %%
df2 = df.ix[3:]
df2.reset_index(drop = True, inplace = True)
df2.head()
# Out:
#            author                                            comment  \
# 0        spike501  \n\tTC - the new fields are in the Llanos basi...
# 1  Tank Commander  \n\nHi All\n\nJust to say I was puzzled by the...
# 2     bigwavedave  \nhttp://www.iii.co.uk/articles/271031/3-oil-s...
# 3          fadilz  \n\tsorry meant to respond rather than tick up...
# 4        celeriac  \n\tanyone got an estimate for the release dat...
#
#                  date                            subject         tag  votes
# 0 2015-10-13 13:26:00  Re: New oil fields and pipe lines      NO TAG      1
# 1 2015-10-10 00:00:00      New oil fields and pipe lines      NO TAG      0
# 2 2015-10-09 00:00:00        3 oil stocks set to double?  Strong BUY      0
# 3 2015-10-09 00:00:00                Re: Loto-2 results?      NO TAG      0
# 4 2015-10-09 00:00:00                    Loto-2 results?      NO TAG      1

# %%
df2.to_pickle("Data/III/AMER.L.pkl")
